# %% [markdown]
# # Revenue Loss Due to Downgrades & Churn.
#
# Business Problem Customers are either downgrading plans or cancelling, leading to revenue leakage.
#
# Key Questions How much Monthly Recurring Revenue (MRR) is lost due to churn?
#
# Which plans experience frequent downgrades?
#
# Are pricing or features causing dissatisfaction?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
subs = pd.read_csv('../data/ravenstack_subscriptions.csv')
subs
# Out:
#      subscription_id account_id  start_date    end_date   plan_tier  seats  \
# 0           S-8cec59   A-3c1a3f  2023-12-23  2024-04-12  Enterprise     14
# 1           S-0f6f44   A-9b9fe9  2024-06-11         NaN         Pro     17
# 2           S-51c0d1   A-659280  2024-11-25         NaN  Enterprise     62
# 3           S-f81687   A-e7a1e2  2024-11-23  2024-12-13  Enterprise      5
# 4           S-cff5a2   A-ba6516  2024-01-10         NaN  Enterprise     27
# ...              ...        ...         ...         ...         ...    ...
# 4995        S-c158df   A-fa2041  2024-10-27         NaN  Enterprise     18
# 4996        S-b49c0a   A-db5e9e  2024-12-05         NaN         Pro     23
# 4997        S-42822d   A-443f6f  2024-12-15         NaN         Pro     25
# 4998        S-432401   A-c7ffc2  2023-05-25         NaN         Pro    132
# 4999        S-71fc3d   A-ccb686  2024-12-06         NaN  Enterprise     10
#
#       mrr_amount  arr_amount  is_trial  upgrade_flag  downgrade_flag  \
# 0           2786       33432     False         False           False
# 1            833        9996     False         False           False
# 2              0           0      True          True           False
# 3            995       11940     False         False           False
# 4           5373       64476     False         False           False
# ...          ...         ...       ...           ...             ...
# 4995        3582       42984     False         False           False
# 4996        1127       13524     False         False           False
# 4997        1225       14700     False         False           False
# 4998        6468       77616     False         False           False
# 4999        1990       23880     False         False           False
#
#       churn_flag billing_frequency  auto_renew_flag
# 0           True           monthly             True
# 1          False           monthly             True
# 2          False            annual            False
# 3           True           monthly             True
# 4          False           monthly             True
# ...          ...               ...              ...
# 4995       False           monthly             True
# 4996       False           monthly            False
# 4997       False            annual             True
# 4998       False           monthly             True
# 4999       False           monthly             True
#
# [5000 rows x 14 columns]

# %%
churn = pd.read_csv('../data/ravenstack_churn_events.csv')
churn
# Out:
#     churn_event_id account_id  churn_date reason_code  refund_amount_usd  \
# 0         C-816288   A-c37cab  2024-10-27     pricing               4.03
# 1         C-5a81e7   A-37f969  2024-06-25     support              96.45
# 2         C-a174be   A-b07346  2024-11-12      budget               0.00
# 3         C-accb39   A-1e50e0  2023-11-01      budget              54.94
# 4         C-92f889   A-956988  2024-12-30     unknown               0.00
# ..             ...        ...         ...         ...                ...
# 595       C-b56a35   A-702032  2024-06-14  competitor               0.00
# 596       C-7e7822   A-dbc825  2024-02-03      budget               0.00
# 597       C-484fba   A-0a282f  2024-12-31     support              62.66
# 598       C-22f536   A-e5d6ab  2024-05-11  competitor               0.00
# 599       C-5e0b68   A-1f559b  2024-09-28    features               0.00
#
#      preceding_upgrade_flag  preceding_downgrade_flag  is_reactivation  \
# 0                     False                     False            False
# 1                      True                     False            False
# 2                     False                     False            False
# 3                     False                     False            False
# 4                     False                      True             True
# ..                      ...                       ...              ...
# 595                   False                     False            False
# 596                   False                     False            False
# 597                   False                      True            False
# 598                    True                     False            False
# 599                   False                     False            False
#
#               feedback_text
# 0    switched to competitor
# 1                       NaN
# 2          missing features
# 3    switched to competitor
# 4             too expensive
# ..                      ...
# 595  switched to competitor
# 596                     NaN
# 597           too expensive
# 598                     NaN
# 599                     NaN
#
# [600 rows x 9 columns]

# %%
account = pd.read_csv('../data/ravenstack_accounts.csv')
account
# Out:
#     account_id account_name    industry country signup_date referral_source  \
# 0     A-2e4581    Company_0      EdTech      US  2024-10-16         partner
# 1     A-43a9e3    Company_1     FinTech      IN  2023-08-17           other
# 2     A-0a282f    Company_2    DevTools      US  2024-08-27         organic
# 3     A-1f0ac7    Company_3  HealthTech      UK  2023-08-27           other
# 4     A-ce550d    Company_4  HealthTech      US  2024-10-27           event
# ..         ...          ...         ...     ...         ...             ...
# 495   A-8ae3fc  Company_495    DevTools      CA  2024-06-28             ads
# 496   A-55f257  Company_496     FinTech      US  2023-12-21         organic
# 497   A-d26ab4  Company_497    DevTools      UK  2024-11-07         organic
# 498   A-712533  Company_498      EdTech      US  2023-07-31         organic
# 499   A-781cc0  Company_499      EdTech      US  2024-09-04         organic
#
#       plan_tier  seats  is_trial  churn_flag
# 0         Basic      9     False       False
# 1         Basic     18     False        True
# 2         Basic      1     False       False
# 3         Basic     24      True       False
# 4    Enterprise     35     False        True
# ..          ...    ...       ...         ...
# 495         Pro      9     False       False
# 496       Basic      9     False       False
# 497       Basic      9     False        True
# 498         Pro     18     False       False
# 499         Pro     12     False       False
#
# [500 rows x 10 columns]

# %%
df = pd.concat([subs, churn, account], axis= 1)
df
# Out:
#      subscription_id  account_id  start_date    end_date   plan_tier seats  \
# 0           S-8cec59    A-3c1a3f  2023-12-23  2024-04-12  Enterprise    14
# 1           S-0f6f44    A-9b9fe9  2024-06-11         NaN         Pro    17
# 2           S-51c0d1    A-659280  2024-11-25         NaN  Enterprise    62
# 3           S-f81687    A-e7a1e2  2024-11-23  2024-12-13  Enterprise     5
# 4           S-cff5a2    A-ba6516  2024-01-10         NaN  Enterprise    27
# ...              ...         ...         ...         ...         ...   ...
# 4995        S-c158df    A-fa2041  2024-10-27         NaN  Enterprise    18
# 4996        S-b49c0a    A-db5e9e  2024-12-05         NaN         Pro    23
# 4997        S-42822d    A-443f6f  2024-12-15         NaN         Pro    25
# 4998        S-432401    A-c7ffc2  2023-05-25         NaN         Pro   132
# 4999        S-71fc3d    A-ccb686  2024-12-06         NaN  Enterprise    10
#
#       mrr_amount  arr_amount  is_trial  upgrade_flag  ...  account_id  \
# 0           2786       33432     False         False  ...    A-2e4581
# 1            833        9996     False         False  ...    A-43a9e3
# 2              0           0      True          True  ...    A-0a282f
# 3            995       11940     False         False  ...    A-1f0ac7
# 4           5373       64476     False         False  ...    A-ce550d
# ...          ...         ...       ...           ...  ...         ...
# 4995        3582       42984     False         False  ...         NaN
# 4996        1127       13524     False         False  ...         NaN
# 4997        1225       14700     False         False  ...         NaN
# 4998        6468       77616     False         False  ...         NaN
# 4999        1990       23880     False         False  ...         NaN
#
#       account_name    industry  country signup_date referral_source  \
# 0        Company_0      EdTech       US  2024-10-16         partner
# 1        Company_1     FinTech       IN  2023-08-17           other
# 2        Company_2    DevTools       US  2024-08-27         organic
# 3        Company_3  HealthTech       UK  2023-08-27           other
# 4        Company_4  HealthTech       US  2024-10-27           event
# ...            ...         ...      ...         ...             ...
# 4995           NaN         NaN      NaN         NaN             NaN
# 4996           NaN         NaN      NaN         NaN             NaN
# 4997           NaN         NaN      NaN         NaN             NaN
# 4998           NaN         NaN      NaN         NaN             NaN
# 4999           NaN         NaN      NaN         NaN             NaN
#
#        plan_tier seats  is_trial churn_flag
# 0          Basic   9.0     False      False
# 1          Basic  18.0     False       True
# 2          Basic   1.0     False      False
# 3          Basic  24.0      True      False
# 4     Enterprise  35.0     False       True
# ...          ...   ...       ...        ...
# 4995         NaN   NaN       NaN        NaN
# 4996         NaN   NaN       NaN        NaN
# 4997         NaN   NaN       NaN        NaN
# 4998         NaN   NaN       NaN        NaN
# 4999         NaN   NaN       NaN        NaN
#
# [5000 rows x 33 columns]

# %% [markdown]
# # Data Cleaning

# %%
df.info() # information about the data.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   subscription_id           5000 non-null   object
#  1   account_id                5000 non-null   object
#  2   start_date                5000 non-null   object
#  3   end_date                  486 non-null    object
#  4   plan_tier                 5000 non-null   object
#  5   seats                     5000 non-null   int64
#  6   mrr_amount                5000 non-null   int64
#  7   arr_amount                5000 non-null   int64
#  8   is_trial                  5000 non-null   bool
#  9   upgrade_flag              5000 non-null   bool
#  10  downgrade_flag            5000 non-null   bool
#  11  churn_flag                5000 non-null   bool
#  12  billing_frequency         5000 non-null   object
#  13  auto_renew_flag           5000 non-null   bool
#  14  churn_event_id            600 non-null    object
#  15  account_id                600 non-null    object
#  16  churn_date                600 non-null    object
#  17  reason_code               600 non-null    object
#  18  refund_amount_usd         600 non-null    float64
#  19  preceding_upgrade_flag    600 non-null    object
#  20  preceding_downgrade_flag  600 non-null    object
#  21  is_reactivation           600 non-null    object
#  22  feedback_text             452 non-null    object
#  23  account_id                500 non-null    object
#  24  account_name              500 non-null    object
#  25  industry                  500 non-null    object
#  26  country                   500 non-null    object
#  27  signup_date               500 non-null    object
#  28  referral_source           500 non-null    object
#  29  plan_tier                 500 non-null    object
#  30  seats                     500 non-null    float64
#  31  is_trial                  500 non-null    object
#  32  churn_flag                500 non-null    object
# dtypes: bool(5), float64(2), int64(3), object(23)
# memory usage: 1.1+ MB

# %%
df.isnull() # check the missing value
# Out:
#       subscription_id  account_id  start_date  end_date  plan_tier  seats  \
# 0               False       False       False     False      False  False
# 1               False       False       False      True      False  False
# 2               False       False       False      True      False  False
# 3               False       False       False     False      False  False
# 4               False       False       False      True      False  False
# ...               ...         ...         ...       ...        ...    ...
# 4995            False       False       False      True      False  False
# 4996            False       False       False      True      False  False
# 4997            False       False       False      True      False  False
# 4998            False       False       False      True      False  False
# 4999            False       False       False      True      False  False
#
#       mrr_amount  arr_amount  is_trial  upgrade_flag  ...  account_id  \
# 0          False       False     False         False  ...       False
# 1          False       False     False         False  ...       False
# 2          False       False     False         False  ...       False
# 3          False       False     False         False  ...       False
# 4          False       False     False         False  ...       False
# ...          ...         ...       ...           ...  ...         ...
# 4995       False       False     False         False  ...        True
# 4996       False       False     False         False  ...        True
# 4997       False       False     False         False  ...        True
# 4998       False       False     False         False  ...        True
# 4999       False       False     False         False  ...        True
#
#       account_name  industry  country  signup_date  referral_source  \
# 0            False     False    False        False            False
# 1            False     False    False        False            False
# 2            False     False    False        False            False
# 3            False     False    False        False            False
# 4            False     False    False        False            False
# ...            ...       ...      ...          ...              ...
# 4995          True      True     True         True             True
# 4996          True      True     True         True             True
# 4997          True      True     True         True             True
# 4998          True      True     True         True             True
# 4999          True      True     True         True             True
#
#       plan_tier  seats  is_trial  churn_flag
# 0         False  False     False       False
# 1         False  False     False       False
# 2         False  False     False       False
# 3         False  False     False       False
# 4         False  False     False       False
# ...         ...    ...       ...         ...
# 4995       True   True      True        True
# 4996       True   True      True        True
# 4997       True   True      True        True
# 4998       True   True      True        True
# 4999       True   True      True        True
#
# [5000 rows x 33 columns]

# %%
# fill the missing value inside the numeric column.

df.fillna(df.mean(numeric_only= True), inplace= True) # fill the numeric column value using fillna() and dropna().
df.dropna(inplace= True)

# %%
# fill missing value in categorical column using mode.

categorical_cols = df.select_dtypes(include= ['object']).columns

for col in categorical_cols:
    m = df[col].mode(dropna= True) 
    if not m.empty:
        df[col] = df[col].fillna(m.iloc[0])
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_21416\4245578170.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col] = df[col].fillna(m.iloc[0])

# %%
df.drop_duplicates(inplace= True) # remove the duplicates value in the dataset

# %%
df
# Out:
#     subscription_id  account_id  start_date    end_date   plan_tier seats  \
# 0          S-8cec59    A-3c1a3f  2023-12-23  2024-04-12  Enterprise    14
# 3          S-f81687    A-e7a1e2  2024-11-23  2024-12-13  Enterprise     5
# 16         S-13939b    A-86902e  2023-07-21  2024-08-03         Pro    34
# 17         S-9333c5    A-ef84cf  2024-06-06  2024-08-13       Basic     8
# 21         S-3bd427    A-2e3bad  2024-12-04  2024-12-27       Basic    61
# 29         S-c75159    A-bcf87c  2024-08-22  2024-09-28  Enterprise    31
# 52         S-aff55c    A-bb2f49  2024-01-14  2024-12-29         Pro     8
# 73         S-0267b7    A-65a46c  2024-10-17  2024-12-04  Enterprise    13
# 78         S-ce5450    A-0a282f  2024-12-25  2024-12-28         Pro     8
# 86         S-09cdac    A-82861f  2024-07-31  2024-09-04       Basic    41
# 93         S-0cb6ed    A-ac85cd  2024-11-09  2024-12-18         Pro    53
# 124        S-1bd2ec    A-e60f9d  2024-12-25  2024-12-28       Basic    38
# 132        S-401496    A-68f37c  2023-08-13  2024-06-22  Enterprise     4
# 134        S-017e33    A-f9cc74  2024-11-08  2024-11-25       Basic    53
# 140        S-9b2c95    A-e60f9d  2024-11-24  2024-12-05         Pro    29
# 143        S-0b0ffa    A-180abf  2024-01-17  2024-04-19       Basic    64
# 168        S-431c03    A-e4bf56  2024-12-02  2024-12-19  Enterprise    37
# 171        S-396a84    A-5b4ebb  2024-10-23  2024-11-27       Basic    21
# 176        S-bbafad    A-854864  2024-12-27  2024-12-30       Basic    20
# 184        S-7904d3    A-d4e0d4  2024-11-30  2024-12-03  Enterprise   117
# 204        S-f5f5b3    A-89ee83  2024-12-26  2024-12-29       Basic    10
# 205        S-4afb53    A-40de06  2023-12-12  2024-12-29  Enterprise    28
# 213        S-85796b    A-f19409  2024-08-27  2024-10-31  Enterprise    23
# 226        S-4bef15    A-600734  2024-08-14  2024-09-22  Enterprise    29
# 256        S-61e53d    A-d42431  2024-11-15  2024-12-14       Basic    22
# 270        S-93fab3    A-9f9299  2024-11-10  2024-12-31         Pro    28
# 277        S-24ae40    A-328bd0  2024-02-11  2024-03-28       Basic    18
# 331        S-321498    A-3a7284  2024-12-25  2024-12-31         Pro    31
# 336        S-627cfa    A-9bfc9f  2023-09-19  2024-01-04         Pro    53
# 354        S-2e017b    A-432483  2023-04-02  2023-04-05         Pro     5
# 360        S-63e282    A-6a4e2d  2024-10-15  2024-11-07         Pro    14
# 361        S-ef2a21    A-427b69  2024-11-28  2024-12-09         Pro    36
# 368        S-42aaf0    A-6da850  2024-12-31  2024-12-31       Basic     6
# 380        S-c4c9ce    A-625d0b  2024-11-16  2024-11-22  Enterprise    10
# 382        S-fc1114    A-4c56c9  2024-07-17  2024-10-23         Pro    18
# 408        S-a554da    A-712f1c  2024-04-09  2024-07-23  Enterprise    17
# 410        S-984f8b    A-db5e9e  2024-12-28  2024-12-28  Enterprise    17
# 418        S-94cfff    A-439b2f  2024-04-16  2024-05-18         Pro    22
# 435        S-f49e0b    A-7f6b86  2024-01-21  2024-03-21         Pro    45
# 440        S-f243c1    A-e888d1  2024-03-12  2024-12-28         Pro    14
# 449        S-a346d6    A-0a282f  2024-08-31  2024-09-25  Enterprise    19
# 451        S-b4212b    A-10b8da  2023-05-12  2024-01-21  Enterprise    17
# 471        S-8a9db8    A-474ad4  2024-11-30  2024-12-07  Enterprise     8
# 481        S-f965de    A-ab438f  2024-10-20  2024-12-18         Pro    64
#
#      mrr_amount  arr_amount  is_trial  upgrade_flag  ...  account_id  \
# 0          2786       33432     False         False  ...    A-2e4581
# 3           995       11940     False         False  ...    A-1f0ac7
# 16            0           0      True         False  ...    A-463db0
# 17          152        1824     False         False  ...    A-ce66f8
# 21         1159       13908     False         False  ...    A-c42f1f
# 29         6169       74028     False         False  ...    A-b20d99
# 52            0           0      True         False  ...    A-02fac6
# 73            0           0      True         False  ...    A-9174e0
# 78            0           0      True         False  ...    A-432483
# 86          779        9348     False         False  ...    A-40a557
# 93         2597       31164     False         False  ...    A-3a7284
# 124         722        8664     False         False  ...    A-5a184f
# 132         796        9552     False          True  ...    A-ae052e
# 134        1007       12084     False         False  ...    A-96e141
# 140           0           0      True         False  ...    A-50f3f7
# 143           0           0      True         False  ...    A-df10db
# 168        7363       88356     False         False  ...    A-794a0b
# 171         399        4788     False         False  ...    A-9779ad
# 176         380        4560     False         False  ...    A-39b19f
# 184       23283      279396     False         False  ...    A-a1b80b
# 204         190        2280     False         False  ...    A-af0cd2
# 205        5572       66864     False         False  ...    A-bd4513
# 213        4577       54924     False         False  ...    A-05d3b3
# 226           0           0      True         False  ...    A-76fa4d
# 256         418        5016     False         False  ...    A-3ce5b8
# 270        1372       16464     False         False  ...    A-902ef7
# 277         342        4104     False         False  ...    A-4e960a
# 331           0           0      True         False  ...    A-712f1c
# 336        2597       31164     False         False  ...    A-c9bb3e
# 354         245        2940     False         False  ...    A-b54c01
# 360         686        8232     False          True  ...    A-f9cc74
# 361        1764       21168     False         False  ...    A-ed510f
# 368         114        1368     False         False  ...    A-1f0636
# 380        1990       23880     False         False  ...    A-0354fe
# 382         882       10584     False         False  ...    A-f5641b
# 408        3383       40596     False         False  ...    A-751bd4
# 410        3383       40596     False         False  ...    A-ad3abd
# 418           0           0      True         False  ...    A-f6b2fb
# 435        2205       26460     False          True  ...    A-39ddf4
# 440           0           0      True         False  ...    A-cc1d8d
# 449        3781       45372     False         False  ...    A-4c56c9
# 451        3383       40596     False          True  ...    A-4a267b
# 471        1592       19104     False         False  ...    A-ccabf0
# 481           0           0      True          True  ...    A-9c18c4
#
#      account_name       industry  country signup_date referral_source  \
# 0       Company_0         EdTech       US  2024-10-16         partner
# 3       Company_3     HealthTech       UK  2023-08-27           other
# 16     Company_16     HealthTech       US  2024-12-05         partner
# 17     Company_17         EdTech       CA  2023-08-23           event
# 21     Company_21     HealthTech       US  2024-07-28           other
# 29     Company_29     HealthTech       IN  2023-09-27           other
# 52     Company_52        FinTech       US  2023-04-06           event
# 73     Company_73  Cybersecurity       US  2024-12-04         partner
# 78     Company_78  Cybersecurity       US  2023-02-06             ads
# 86     Company_86  Cybersecurity       AU  2023-12-03         partner
# 93     Company_93        FinTech       US  2024-11-17         organic
# 124   Company_124       DevTools       DE  2023-06-19           other
# 132   Company_132        FinTech       CA  2023-09-11           other
# 134   Company_134       DevTools       UK  2023-08-12         partner
# 140   Company_140     HealthTech       US  2023-12-22         partner
# 143   Company_143       DevTools       US  2023-06-06           other
# 168   Company_168     HealthTech       DE  2023-06-02         organic
# 171   Company_171  Cybersecurity       AU  2024-03-29           event
# 176   Company_176        FinTech       US  2023-02-03         partner
# 184   Company_184     HealthTech       US  2023-11-27         organic
# 204   Company_204  Cybersecurity       IN  2023-01-03           other
# 205   Company_205       DevTools       AU  2024-11-06           event
# 213   Company_213       DevTools       AU  2023-05-28             ads
# 226   Company_226     HealthTech       US  2024-11-24           event
# 256   Company_256        FinTech       IN  2023-09-07             ads
# 270   Company_270     HealthTech       US  2024-09-03           other
# 277   Company_277        FinTech       US  2024-01-17           other
# 331   Company_331       DevTools       US  2023-12-16             ads
# 336   Company_336         EdTech       US  2024-03-24             ads
# 354   Company_354       DevTools       US  2024-09-29           event
# 360   Company_360       DevTools       FR  2024-10-12         partner
# 361   Company_361  Cybersecurity       IN  2023-01-17         partner
# 368   Company_368         EdTech       AU  2024-01-01         partner
# 380   Company_380  Cybersecurity       US  2024-10-22           other
# 382   Company_382         EdTech       US  2024-03-30           other
# 408   Company_408  Cybersecurity       UK  2024-07-12         partner
# 410   Company_410        FinTech       US  2023-03-03           event
# 418   Company_418       DevTools       AU  2024-04-23           event
# 435   Company_435         EdTech       US  2024-12-05         partner
# 440   Company_440        FinTech       US  2024-12-08           other
# 449   Company_449        FinTech       US  2023-12-20         partner
# 451   Company_451        FinTech       US  2024-05-05           other
# 471   Company_471     HealthTech       IN  2023-11-06         organic
# 481   Company_481     HealthTech       US  2023-07-27             ads
#
#       plan_tier  seats  is_trial  churn_flag
# 0         Basic    9.0     False       False
# 3         Basic   24.0      True       False
# 16        Basic   15.0     False       False
# 17          Pro   29.0     False       False
# 21          Pro    8.0     False       False
# 29        Basic   20.0     False       False
# 52          Pro   22.0     False       False
# 73        Basic   37.0     False       False
# 78          Pro    4.0     False       False
# 86          Pro   16.0      True       False
# 93   Enterprise   31.0     False       False
# 124  Enterprise    1.0     False        True
# 132       Basic   39.0     False       False
# 134       Basic   14.0     False       False
# 140       Basic   31.0     False        True
# 143  Enterprise    2.0      True       False
# 168       Basic   23.0     False       False
# 171         Pro   40.0      True        True
# 176  Enterprise    1.0     False       False
# 184       Basic   16.0     False       False
# 204  Enterprise   19.0      True       False
# 205  Enterprise   50.0      True       False
# 213       Basic    9.0      True       False
# 226         Pro   69.0     False       False
# 256       Basic    8.0     False        True
# 270  Enterprise   83.0     False        True
# 277  Enterprise   12.0      True        True
# 331       Basic   17.0     False        True
# 336         Pro    5.0     False       False
# 354  Enterprise   29.0     False       False
# 360  Enterprise   30.0      True       False
# 361       Basic   42.0     False       False
# 368         Pro  105.0     False       False
# 380       Basic   34.0     False       False
# 382         Pro   31.0     False       False
# 408         Pro   10.0     False       False
# 410         Pro   44.0     False       False
# 418       Basic   23.0     False       False
# 435  Enterprise   40.0     False       False
# 440         Pro    5.0     False       False
# 449  Enterprise    9.0     False        True
# 451         Pro   25.0     False       False
# 471         Pro    1.0     False       False
# 481         Pro   11.0     False        True
#
# [44 rows x 33 columns]
